# %%
import pandas as pd 
import seaborn as sns
import  numpy as np 
import matplotlib.pyplot as plt 

df= pd.read_csv(r"C:\Users\yigit\Downloads\creditcard.csv(1)\creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
plt.figure(figsize=(6,6))
sns.countplot(x='Class', data=df, palette='pastel')
plt.title('Class Distribution (0: Non-Fraud, 1: Fraud)')
plt.xlabel('Transaction Class')
plt.ylabel('Count')
plt.show()

fraud_count = df['Class'].value_counts()[1]
non_fraud_count = df['Class'].value_counts()[0]
# Out:
# C:\Users\yigit\AppData\Local\Temp\ipykernel_5788\486380316.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Class', data=df, palette='pastel')

# %%
corr_matrix = df.corr()

plt.figure(figsize=(14,10))
sns.heatmap(corr_matrix, cmap='coolwarm', vmax=0.8)
plt.title('Correlation Heatmap of Features')
plt.show()

correlation_with_class = corr_matrix['Class'].sort_values(ascending=False)
print(correlation_with_class.head(10))
# Out:
# Class    1.000000
# V11      0.154876
# V4       0.133447
# V2       0.091289
# V21      0.040413
# V19      0.034783
# V20      0.020090
# V8       0.019875
# V27      0.017580
# V28      0.009536
# Name: Class, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler

df_scaled = df.copy()

scaler = StandardScaler()

df_scaled['Amount'] = scaler.fit_transform(df[['Amount']])
df_scaled['Time'] = scaler.fit_transform(df[['Time']])

# %%
from sklearn.model_selection import train_test_split

X = df_scaled.drop('Class', axis=1)
y = df_scaled['Class']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42)

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %%
from sklearn.linear_model import LogisticRegression

lr_model = LogisticRegression(solver='liblinear', random_state=42)
lr_model.fit(X_train_resampled, y_train_resampled)

lr_preds = lr_model.predict(X_test)
lr_probs = lr_model.predict_proba(X_test)[:, 1]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, lr_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99     56864
#            1       0.06      0.92      0.11        98
#
#     accuracy                           0.97     56962
#    macro avg       0.53      0.95      0.55     56962
# weighted avg       1.00      0.97      0.99     56962

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, lr_preds)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Logistic Regression: Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score

fpr, tpr, _ = roc_curve(y_test, lr_probs)
auc_score = roc_auc_score(y_test, lr_probs)

plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label=f"LR (AUC = {auc_score:.2f})", linewidth=2)
plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate (Recall)")
plt.title("ROC Curve: Logistic Regression")
plt.legend()
plt.grid()
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=20,max_depth=5, n_jobs=-1 , random_state=42)
rf_model.fit(X_train_resampled, y_train_resampled)

rf_preds = rf_model.predict(X_test)
rf_probs = rf_model.predict_proba(X_test)[:, 1]

# %%
from sklearn.metrics import classification_report
print("=== Random Forest Classification Report ===")
print(classification_report(y_test, rf_preds))
# Out:
# === Random Forest Classification Report ===
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     56864
#            1       0.15      0.89      0.25        98
#
#     accuracy                           0.99     56962
#    macro avg       0.57      0.94      0.62     56962
# weighted avg       1.00      0.99      0.99     56962

# %%
cm = confusion_matrix(y_test, rf_preds)

sns.heatmap(cm, annot=True, fmt='d', cmap='Greens')
plt.title("Random Forest: Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
fpr, tpr, _ = roc_curve(y_test, rf_probs)
auc_score = roc_auc_score(y_test, rf_probs)

plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label=f"Random Forest (AUC = {auc_score:.2f})", linewidth=2)
plt.plot([0,1],[0,1], linestyle='--', color='gray')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate (Recall)")
plt.title("ROC Curve: Random Forest")
plt.legend()
plt.grid()
plt.show()

# %%
from xgboost import XGBClassifier

xgb_model = XGBClassifier(
    n_estimators=100,
    max_depth=5,
    learning_rate=0.1,
    scale_pos_weight= (len(y_train_resampled) - sum(y_train_resampled)) / sum(y_train_resampled),
    use_label_encoder=False,
    eval_metric='logloss',
    random_state=42
)

xgb_model.fit(X_train_resampled, y_train_resampled)

xgb_preds = xgb_model.predict(X_test)

xgb_probs = xgb_model.predict_proba(X_test)[:, 1]
# Out:
# C:\Users\yigit\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [19:27:26] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
print("=== XGBoost Classification Report ===")
print(classification_report(y_test, xgb_preds))
# Out:
# === XGBoost Classification Report ===
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.24      0.89      0.38        98
#
#     accuracy                           0.99     56962
#    macro avg       0.62      0.94      0.69     56962
# weighted avg       1.00      0.99      1.00     56962

# %%
cm = confusion_matrix(y_test, xgb_preds)
sns.heatmap(cm, annot=True, fmt='d', cmap='Purples')
plt.title("XGBoost: Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %%
fpr, tpr, _ = roc_curve(y_test, xgb_probs)
auc_score = roc_auc_score(y_test, xgb_probs)

plt.figure(figsize=(8,6))
plt.plot(fpr, tpr, label=f"XGBoost (AUC = {auc_score:.2f})", linewidth=2)
plt.plot([0,1], [0,1], linestyle='--', color='gray')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate (Recall)")
plt.title("ROC Curve: XGBoost")
plt.legend()
plt.grid()
plt.show()

# %%
comparison_data = {
    'Model': ['Logistic Regression', 'Random Forest', 'XGBoost'],
    'Recall': [0.92, 0.89, 0.89],
    'Precision': [0.06, 0.15, 0.24],
    'F1-score': [0.12, 0.25, 0.38],
    'AUC': [0.97, 0.98, 0.98],
    'False Positives': [1461, 504, 277],
    'False Negatives': [8, 11, 11]
}

df_compare = pd.DataFrame(comparison_data)

# %%
metrics_to_plot = ['Recall', 'Precision', 'F1-score', 'AUC']
df_compare.set_index('Model')[metrics_to_plot].plot(kind='bar', figsize=(10, 6))

plt.title('📊 Model Comparison: Fraud Detection')
plt.ylabel('Score')
plt.ylim(0, 1.1)
plt.xticks(rotation=0)
plt.legend(loc='lower right')
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\yigit\AppData\Local\Temp\ipykernel_5788\1179456343.py:10: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   plt.tight_layout()
# C:\Users\yigit\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from tabulate import tabulate
print(tabulate(df_compare, headers='keys', tablefmt='github', showindex=False))
# Out:
# | Model               |   Recall |   Precision |   F1-score |   AUC |   False Positives |   False Negatives |
# |---------------------|----------|-------------|------------|-------|-------------------|-------------------|
# | Logistic Regression |     0.92 |        0.06 |       0.12 |  0.97 |              1461 |                 8 |
# | Random Forest       |     0.89 |        0.15 |       0.25 |  0.98 |               504 |                11 |
# | XGBoost             |     0.89 |        0.24 |       0.38 |  0.98 |               277 |                11 |
